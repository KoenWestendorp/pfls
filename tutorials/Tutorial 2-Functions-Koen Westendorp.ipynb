# %% [markdown]
# # Tutorial 2---Functions
#
# _2023-03-21_
#
# Koen Westendorp (they/them hen/hun)
#
# [k.s.s.westendorp@student.rug.nl](mailto:k.s.s.westendorp@student.rug.nl)

# %% [markdown]
# ![image.png](attachment:c389a839-2f58-44f3-a189-224410bd3b7c.png)

# %% [markdown]
# ## What do we know about functions?

# %%
# Why?

# When?

# %%
# Creating one

# %%
# Documenting functions

# Why?

# How?

# %%
# Returning

# %%
# Default parameters

# %%
# Scope

# %% [markdown]
# ## A problem
#
# Say we have three lists of things. We have one list of book titles:
#
#
# ```
# De wetten
# Darwinian Populations
# The Social Construction of What?
# The Right to Sex
# Enactive Psychiatry
# ```
#
# authors:
#
# ```
# Connie Palmen
# Peter Godfrey-Smith
# Ian Hacking
# Amia Srinivasan
# Sanneke de Haan
# ```
#
# and years:
#
# ```
# 1991
# 2009
# 1999
# 2021
# 2021
# ```
#
# They are in the same order, but not together.
#
# **We want to print a nice list of _aaallllll_ the books we have.**
#
# Oh gosh, we have too many books and too little automation... What can we do about that???

# %%
# Let's write the book titles in a nice enumerated list. Like this
# 
# 1. De wetten
# 2. Darwinian Populations
# 3. ...

# %%
# Can we use a function that gives us the number and the book 
# title as a list of pairs? Like this:
# 
# 1. Connie Palmen, De wetten

# %%
# How can we also add the year?
# What would a good docstring be?

# %%
# Can we write the year in parentheses?
# Is it nice to use a seperate function for that?
# When is that the case, and when not?

# %%
# Okay, what if we want to cut off the books past a certain age?
